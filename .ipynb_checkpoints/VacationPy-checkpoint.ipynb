# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")


# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
import hvplot.pandas
import pandas as pd

# Load the CSV file into a DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Use hvplot to create a map with points for each city
# The size of each point will represent the humidity
map_plot = city_data_df.hvplot.points(
    'Lng', 'Lat', geo=True, size='Humidity', color='blue', hover_cols=['City', 'Humidity'],
    title='City Humidity Levels', width=900, height=600
)

# Display the map
map_plot
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="b33d35ef-a89d-455d-9d49-f1104cc32327" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# Criteria: max temperature between 10°C and 30°C, humidity less than 30%, wind speed less than 4.5 m/s, and zero cloudiness
filtered_cities_df = city_data_df[
    (city_data_df['Max Temp'] >= 10) &
    (city_data_df['Max Temp'] <= 30) &
    (city_data_df['Humidity'] < 30) &
    (city_data_df['Wind Speed'] < 4.5) &
    (city_data_df['Cloudiness'] == 0)
]

# Drop any rows with null values
filtered_cities_df = filtered_cities_df.dropna()

# Print the number of rows in the filtered DataFrame
print(f"Number of cities after filtering: {len(filtered_cities_df)}")

# Display sample data
filtered_cities_df.head()
# Out:
# Number of cities after filtering: 4
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 96        96       zhangye  38.9342  100.4517     11.11        16           0
# 436      436  lakki marwat  32.6079   70.9114     27.89        20           0
# 496      496        tikrit  34.6071   43.6782     29.02        14           0
# 550      550          pali  25.7667   73.3333     27.18        26           0
#
#      Wind Speed Country        Date
# 96         1.67      CN  1666108292
# 436        1.53      PK  1666108492
# 496        1.41      IQ  1666108524
# 550        1.38      IN  1666108552

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = filtered_cities_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df.head()
# Out:
#              City Country      Lat       Lng  Humidity Hotel Name
# 96        zhangye      CN  38.9342  100.4517        16
# 436  lakki marwat      PK  32.6079   70.9114        20
# 496        tikrit      IQ  34.6071   43.6782        14
# 550          pali      IN  25.7667   73.3333        26

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Import the requests module
import requests
# Import API key
from api_keys import geoapify_key

# Set parameters to search for a hotel
radius = 10000  # 10,000 meters (10 km)
params = {
    'apiKey': geoapify_key,
    'radius': radius,
    'type': 'hotel'
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude, longitude from the DataFrame
    lat = row['Lat']
    lng = row['Lng']

    # Add the current city's latitude and longitude to the params dictionary
    params["lat"] = lat
    params["lon"] = lng

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionary
    response = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = response.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df.head()
# Out:
# Starting hotel search
# zhangye - nearest hotel: No hotel found
# lakki marwat - nearest hotel: No hotel found
# tikrit - nearest hotel: No hotel found
# pali - nearest hotel: No hotel found
#              City Country      Lat       Lng  Humidity      Hotel Name
# 96        zhangye      CN  38.9342  100.4517        16  No hotel found
# 436  lakki marwat      PK  32.6079   70.9114        20  No hotel found
# 496        tikrit      IQ  34.6071   43.6782        14  No hotel found
# 550          pali      IN  25.7667   73.3333        26  No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Import necessary libraries
import geoviews as gv
import geoviews.tile_sources as gvts
import hvplot.pandas

# Define the tile source (optional, choose different tile sources as needed)
tile_opts = dict(width=800, height=600, xaxis=None, yaxis=None, show_grid=False)
tiles = gv.tile_sources.CartoLight.options(**tile_opts)

# Create GeoViews dataset from hotel_df for plotting points
points = hotel_df.hvplot.points('Lng', 'Lat', hover_cols=['City', 'Hotel Name'], 
                                geo=True, tiles=tiles, size=20, alpha=0.7)

# Display the map
gv.output(points)
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name)
